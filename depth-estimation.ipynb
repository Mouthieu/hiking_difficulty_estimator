# %% [markdown]
# # Estimation de la profondeur d'une image 2D

# %% [markdown]
# Dans ce notebook, nous allons utiliser un modèle de fondation nommé **Depth-anything** pour estimer la profondeur des images satellites de notre dataset.
#
# Le dataset utilisé est accessible via ce lien : [DOTAv2 Dataset](https://huggingface.co/datasets/satellite-image-deep-learning/DOTAv2?sql=--+The+SQL+console+is+powered+by+DuckDB+WASM+and+runs+entirely+in+the+browser.%0A--+Get+started+by+typing+a+query+or+selecting+a+view+from+the+options+below.%0ASELECT+*+FROM+train+LIMIT+10%3B)

# %% [markdown]
# ## Etape 1 : Importation des librairies nécessaires

# %%
import PIL

# %% [markdown]
# ## Etape 2 : Importation du dataset

# %%
from datasets import load_dataset, Image

ds = load_dataset("satellite-image-deep-learning/DOTAv2")

# %%
ds['train'][0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1054x1529>
